# %% [markdown]
# <a href="https://colab.research.google.com/github/ay30n591/first/blob/master/%EB%AF%B8%EB%8B%88%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B82_%EC%9E%91%EC%97%85_0615_2_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore', category=Warning)
df=pd.read_csv('mbti_col.csv')
df
# Out:
#         Unnamed: 0                                              posts  type  \
# 0                0  know intj tool use interaction people excuse a...  INTJ
# 1                1  rap music ehh opp yeah know valid well know fa...  INTJ
# 2                2  preferably p hd low except wew lad video p min...  INTJ
# 3                3  drink like wish could drink red wine give head...  INTJ
# 4                4  space program ah bad deal meing freelance max ...  INTJ
# ...            ...                                                ...   ...
# 106062      106062  stay frustrate world life want take long nap w...  INFP
# 106063      106063  fizzle around time mention sure mistake thing ...  INFP
# 106064      106064  schedule modify hey w intp strong wing underst...  INFP
# 106065      106065  enfj since january busy schedule able spend li...  INFP
# 106066      106066  feel like men good problem tell parent want te...  INFP
#
#         E/I  S/N  T/F  J/P
# 0         0    0    1    1
# ...

# %%
from nltk.corpus import stopwords
filtered_df_0 = df[df['S/N'] == 0]
stop_words_list = stopwords.words('english')

from nltk.tokenize import word_tokenize
# from nltk.corpus import stopwords: 모듈에서 불용어 말뭉치를 가져옵니다
from nltk.corpus import stopwords

def preprocess_text(text):
    tokens = word_tokenize(text)
    text = text.lower()

# 영어 불용어 로드
    stop_words = stopwords.words('english')
# 불용어 추가
    stop_words.extend(['mbti', 'infj', 'intj', 'infp', 'intp', 'enfj', 'entj', 'enfp', 'entp', 'isfj', 'istj'
          , 'isfp', 'istp', 'esfj', 'estj', 'esfp', 'estp', 'personality', 'type'
          ,'like','think','people','get', 'thing','make', 'know', 'feel','one', 'go'
          ,'know','time','really','good','feel','want','see','way','also'])

    tokens = [word for word in tokens if word not in stop_words]

    return tokens

filtered_df_0['processed_posts'] = filtered_df_0['posts'].apply(preprocess_text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 25
#      21     tokens = [word for word in tokens if word not in stop_words]
#      23     return tokens
# ---> 25 filtered_df_0['processed_posts'] = filtered_df_0['posts'].apply(preprocess_text)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
# ...

# %%
from nltk.corpus import stopwords
filtered_df_1 = df[df['S/N'] == 1]
stop_words_list = stopwords.words('english')

from nltk.tokenize import word_tokenize
# from nltk.corpus import stopwords: 모듈에서 불용어 말뭉치를 가져옵니다
from nltk.corpus import stopwords

def preprocess_text(text):
    tokens = word_tokenize(text)
    text = text.lower()

# 영어 불용어 로드
    stop_words = stopwords.words('english')
# 불용어 추가
    stop_words.extend(['mbti', 'infj', 'intj', 'infp', 'intp', 'enfj', 'entj', 'enfp', 'entp', 'isfj', 'istj'
          , 'isfp', 'istp', 'esfj', 'estj', 'esfp', 'estp', 'personality', 'type'
          ,'like','think','people','get', 'thing','make', 'know', 'feel','one', 'go'
          ,'know','time','really','good','feel','want','see','way','also'])

    tokens = [word for word in tokens if word not in stop_words]

    return tokens

filtered_df_1['processed_posts'] = filtered_df_1['posts'].apply(preprocess_text)
concatenated_df = pd.concat([filtered_df_1, filtered_df_0], axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 25
#      21     tokens = [word for word in tokens if word not in stop_words]
#      23     return tokens
# ---> 25 filtered_df_1['processed_posts'] = filtered_df_1['posts'].apply(preprocess_text)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
# ...

# %%
preprocess_text

# %%
filtered_df_0
# Out:
#         Unnamed: 0                                              posts  type  \
# 0                0  know intj tool use interaction people excuse a...  INTJ
# 1                1  rap music ehh opp yeah know valid well know fa...  INTJ
# 2                2  preferably p hd low except wew lad video p min...  INTJ
# 3                3  drink like wish could drink red wine give head...  INTJ
# 4                4  space program ah bad deal meing freelance max ...  INTJ
# ...            ...                                                ...   ...
# 106062      106062  stay frustrate world life want take long nap w...  INFP
# 106063      106063  fizzle around time mention sure mistake thing ...  INFP
# 106064      106064  schedule modify hey w intp strong wing underst...  INFP
# 106065      106065  enfj since january busy schedule able spend li...  INFP
# 106066      106066  feel like men good problem tell parent want te...  INFP
#
# ...

# %%
filtered_df_1
# Out:
#        Unnamed: 0                                              posts  type  \
# 47388       47388  like spring feel energetic season whatever rea...  ISFJ
# 47389       47389  ridiculous like stress angry think straight ge...  ISFJ
# 47390       47390  call muiple people bid save face slowly realiz...  ISFJ
# 47391       47391  talk etc end coworkers friend ask hang day rea...  ISFJ
# 47392       47392  ive try learn pick feel apart constantly like ...  ISFJ
# ...           ...                                                ...   ...
# 78965       78965  th say like envisage bad scenario possible kno...  ESTP
# 78966       78966  bubble ngry kick nut ad wear thick rim black g...  ESTP
# 78967       78967  gift estps want test law break law entps want ...  ESTP
# 78968       78968  kevin estj lori enfj robert ne user yep see to...  ESTP
# 78969       78969  ignore time chuck norris oh wait moment rememb...  ESTP
#
# ...

# %%
concatenated_df = pd.concat([filtered_df_1, filtered_df_0], axis=0)

# %%
concatenated_df
# Out:
#         E/I  J/P  S/N  T/F  Unnamed: 0  \
# 47388     0    1    1    0       47388
# 47389     0    1    1    0       47389
# 47390     0    1    1    0       47390
# 47391     0    1    1    0       47391
# 47392     0    1    1    0       47392
# ...     ...  ...  ...  ...         ...
# 106062    0    0    0    0      106062
# 106063    0    0    0    0      106063
# 106064    0    0    0    0      106064
# 106065    0    0    0    0      106065
# 106066    0    0    0    0      106066
#
#                                                     posts  \
# 47388   like spring feel energetic season whatever rea...
# 47389   ridiculous like stress angry think straight ge...
# 47390   call muiple people bid save face slowly realiz...
# 47391   talk etc end coworkers friend ask hang day rea...
# 47392   ive try learn pick feel apart constantly like ...
# ...                                                   ...
# 106062  stay frustrate world life want take long nap w...
# ...
